# %% [markdown]
# # Day 21 · Bulk RNA-seq DE
# Interactive exploration notebook.

# %%
import sys
sys.path.insert(0, '..')
from src.data.simulator import simulate_counts
from src.models.deseq2 import DEAnalysis

counts, meta = simulate_counts(n_samples=12, n_genes=500, seed=42)
de = DEAnalysis(counts, meta)
results = de.run()
results.head(10)
